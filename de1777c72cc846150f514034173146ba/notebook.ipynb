# %% [markdown]
# One of the most exciting possibilities of AI and LLMs are *agents*: tools that
# allow LLMs to interact with various tools in order to solve problems.  You've
# probably seen them before, like when you ask ChatGPT to browse the web for you.
#
# In this blog post, we'll take a look at how to build agents using LangChain.  They'll work great using an OpenAI model.  And then we'll try to run them locally using Ollama, using a variety of open models.  And they will almost all fail miserably.  They fail so bad that I created this blog post to convince myself I wasn't imagining things.
#
# In a future blog post, we will examine why.

# %% [markdown]
# # LangChain

# %% [markdown]
# LangChain is a framework that allows you to build LLM applications.  Basically,
# it abstracts a bunch of different components like LLMs, vector stores, and the
# like, and allows you to focus on your application's logic.  So, you might
# develop your application in LangChain while using a local LLM to run it, but then use
# Claude once you go to production.
#
# Anyway, using LangChain to make a query is pretty simple.

# %%
# !pip install langchain-openai~=0.2.7 python-dotenv
# !pip install httpx==0.27.2 # temp
# Out:
# Collecting langchain-openai~=0.2.7
#   Downloading langchain_openai-0.2.12-py3-none-any.whl.metadata (2.7 kB)
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.21 in /usr/local/lib/python3.10/dist-packages (from langchain-openai~=0.2.7) (0.3.21)
# Collecting openai<2.0.0,>=1.55.3 (from langchain-openai~=0.2.7)
#   Downloading openai-1.57.2-py3-none-any.whl.metadata (24 kB)
# Collecting tiktoken<1,>=0.7 (from langchain-openai~=0.2.7)
#   Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai~=0.2.7) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai~=0.2.7) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai~=0.2.7) (0.1.147)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai~=0.2.7) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai~=0.2.7) (2.10.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai~=0.2.7) (9.0.0)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.21->langchain-openai~=0.2.7) (4.12.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.55.3->langchain-openai~=0.2.7) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.55.3->langchain-openai~=0.2.7) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.55.3->langchain-openai~=0.2.7) (0.28.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.55.3->langchain-openai~=0.2.7) (0.8.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.55.3->langchain-openai~=0.2.7) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai<2.0.0,>=1.55.3->langchain-openai~=0.2.7) (4.66.6)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken<1,>=0.7->langchain-openai~=0.2.7) (2024.9.11)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.10/dist-packages (from tiktoken<1,>=0.7->langchain-openai~=0.2.7) (2.32.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.55.3->langchain-openai~=0.2.7) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.55.3->langchain-openai~=0.2.7) (1.2.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.55.3->langchain-openai~=0.2.7) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.55.3->langchain-openai~=0.2.7) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.55.3->langchain-openai~=0.2.7) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.21->langchain-openai~=0.2.7) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.21->langchain-openai~=0.2.7) (3.10.12)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.21->langchain-openai~=0.2.7) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.21->langchain-openai~=0.2.7) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.21->langchain-openai~=0.2.7) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai~=0.2.7) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai~=0.2.7) (2.2.3)
# Downloading langchain_openai-0.2.12-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 211.5 kB/s eta 0:00:00
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading openai-1.57.2-py3-none-any.whl (389 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 389.9/389.9 kB 23.4 MB/s eta 0:00:00
# Downloading tiktoken-0.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 46.7 MB/s eta 0:00:00
# Installing collected packages: python-dotenv, tiktoken, openai, langchain-openai
#   Attempting uninstall: openai
#     Found existing installation: openai 1.54.5
#     Uninstalling openai-1.54.5:
#       Successfully uninstalled openai-1.54.5
# Successfully installed langchain-openai-0.2.12 openai-1.57.2 python-dotenv-1.0.1 tiktoken-0.8.0
# Collecting httpx==0.27.2
#   Downloading httpx-0.27.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx==0.27.2) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx==0.27.2) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx==0.27.2) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx==0.27.2) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx==0.27.2) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx==0.27.2) (0.14.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx==0.27.2) (1.2.2)
# Downloading httpx-0.27.2-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: httpx
#   Attempting uninstall: httpx
#     Found existing installation: httpx 0.28.0
#     Uninstalling httpx-0.28.0:
#       Successfully uninstalled httpx-0.28.0
# Successfully installed httpx-0.27.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# We'll load my OpenAI API key using dotenv
# %load_ext dotenv
# %dotenv drive/MyDrive/.env

# %%
from langchain_core.tools import tool
from langchain import hub
from langchain_core.messages import AIMessageChunk, HumanMessage

from langchain_openai import ChatOpenAI

# Remove non-determinism for the blog post
zero_temp_gpt35 = ChatOpenAI(model="gpt-3.5-turbo", temperature=0)

response=zero_temp_gpt35.invoke("Hi!  What is your name?").content

import textwrap
print(textwrap.fill(response))
# Out:
# Hello! I am a language model AI assistant. I don't have a personal
# name, but you can call me Assistant. How can I help you today?

# %% [markdown]
# The beauty of LangChain is that the components are modular.  We can replace
# `gpt-3.5-turbo` model with something else later if we want to, and indeed we
# will do just that!

# %% [markdown]
# # Building an Agent using LangGraph
#
# LangGraph is the portion of LangChain for building agents.  It allows us to easily define new tools:

# %%
# !pip install langgraph~=0.2.53
# Out:
# Collecting langgraph~=0.2.53
#   Downloading langgraph-0.2.57-py3-none-any.whl.metadata (15 kB)
# Collecting langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43 (from langgraph~=0.2.53)
#   Downloading langchain_core-0.3.23-py3-none-any.whl.metadata (6.3 kB)
# Collecting langgraph-checkpoint<3.0.0,>=2.0.4 (from langgraph~=0.2.53)
#   Downloading langgraph_checkpoint-2.0.8-py3-none-any.whl.metadata (4.6 kB)
# Collecting langgraph-sdk<0.2.0,>=0.1.42 (from langgraph~=0.2.53)
#   Downloading langgraph_sdk-0.1.43-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph~=0.2.53) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph~=0.2.53) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph~=0.2.53) (0.1.147)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph~=0.2.53) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph~=0.2.53) (2.10.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph~=0.2.53) (9.0.0)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph~=0.2.53) (4.12.2)
# Requirement already satisfied: msgpack<2.0.0,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from langgraph-checkpoint<3.0.0,>=2.0.4->langgraph~=0.2.53) (1.1.0)
# Requirement already satisfied: httpx>=0.25.2 in /usr/local/lib/python3.10/dist-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph~=0.2.53) (0.27.2)
# Requirement already satisfied: orjson>=3.10.1 in /usr/local/lib/python3.10/dist-packages (from langgraph-sdk<0.2.0,>=0.1.42->langgraph~=0.2.53) (3.10.12)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph~=0.2.53) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph~=0.2.53) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph~=0.2.53) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph~=0.2.53) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph~=0.2.53) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph~=0.2.53) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph~=0.2.53) (3.0.0)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph~=0.2.53) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph~=0.2.53) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph~=0.2.53) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph~=0.2.53) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph~=0.2.53) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core!=0.3.0,!=0.3.1,!=0.3.10,!=0.3.11,!=0.3.12,!=0.3.13,!=0.3.14,!=0.3.15,!=0.3.16,!=0.3.17,!=0.3.18,!=0.3.19,!=0.3.2,!=0.3.20,!=0.3.21,!=0.3.22,!=0.3.3,!=0.3.4,!=0.3.5,!=0.3.6,!=0.3.7,!=0.3.8,!=0.3.9,<0.4.0,>=0.2.43->langgraph~=0.2.53) (2.2.3)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.2.0,>=0.1.42->langgraph~=0.2.53) (1.2.2)
# Downloading langgraph-0.2.57-py3-none-any.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.3/134.3 kB 8.5 MB/s eta 0:00:00
# Downloading langchain_core-0.3.23-py3-none-any.whl (410 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 kB 24.0 MB/s eta 0:00:00
# Downloading langgraph_checkpoint-2.0.8-py3-none-any.whl (35 kB)
# Downloading langgraph_sdk-0.1.43-py3-none-any.whl (31 kB)
# Installing collected packages: langgraph-sdk, langchain-core, langgraph-checkpoint, langgraph
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.21
#     Uninstalling langchain-core-0.3.21:
#       Successfully uninstalled langchain-core-0.3.21
# Successfully installed langchain-core-0.3.23 langgraph-0.2.57 langgraph-checkpoint-2.0.8 langgraph-sdk-0.1.43

# %%
@tool
def foobar(input: int) -> int:
    """Computes the foobar function."""
    return input + 2

tools = [foobar]

# %% [markdown]
# The `@tool` decorator automatically transforms the function into a schema that can be used by the LLM to decide whether to invoke the tool, and if so, how.

# %%
foobar.tool_call_schema.model_json_schema()
# Out:
# {'description': 'Computes the foobar function.',
#  'properties': {'input': {'title': 'Input', 'type': 'integer'}},
#  'required': ['input'],
#  'title': 'foobar',
#  'type': 'object'}

# %% [markdown]
# With that, we can build a generic agent, called a [ReAct agent](https://arxiv.org/abs/2210.03629), which can interact with our tools:

# %%
from langgraph.prebuilt import create_react_agent

def react_chat(prompt, model):
  agent_executor = create_react_agent(model, tools)

  response = agent_executor.invoke({"messages": [("user", prompt)]})
  return response['messages'][-1].content, response

last_msg, _ = react_chat("Hi. Please evaluate foobar(30)", zero_temp_gpt35)
print(last_msg)
assert "32" in last_msg, "Uh oh, something went wrong"
# Out:
# The result of evaluating foobar(30) is 32.

# %% [markdown]
# Yes! We did it, team! 🎉  We could change `magic_function` to be a web search, a database lookup, or you name it.
#
# Let's try a query that doesn't use a tool at all.

# %%
last_msg, result = react_chat("Hi.", zero_temp_gpt35)
print(last_msg)
assert "Hello" in last_msg and "foobar" not in last_msg, "Uh oh, something went wrong"
# Out:
# Hello! How can I assist you today?

# %% [markdown]
# Great.  So, in theory, we have an agent that we can chat with and is able to call tools in order to help us out.

# %% [markdown]
# # Hidden: Install Ollama

# %% [markdown]
# Here we install ollama.

# %%
# !ollama 2>/dev/null || curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ############################################################################################# 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %% [markdown]
# Make sure the ollama server is running.

# %%
# !ollama -v
# !ollama ps 2>/dev/null || (env OLLAMA_DEBUG=1 nohup ollama serve &)
# Out:
# Warning: could not connect to a running Ollama instance
# Warning: client version is 0.5.1
# nohup: appending output to 'nohup.out'

# %% [markdown]
# # Ollama: Going Local

# %% [markdown]
# Now let's try to create a tool-wielding agent using a LLM that runs on our local machine.
# We'll do this by using Ollama, which is a (fairly) easy way to run smaller open LLMs on your local machine.  It
# will use any GPUs that you might have, but it's still usable even if you don't
# have any.  After all, you're just performing inference, not training.
#
# Here's an example of me running llama 3.2 with ollama on my work laptop.
#
# ```
# root@be5c1cb9e696:/# ollama run llama3.2
# >>> Hi mom!
# It's nice to hear from you, sweetie. Is everything okay? What's on your mind?
#
# >>> Are you alive?
# I am a computer program, so I don't have feelings or emotions like humans do. But I'm
# designed to simulate conversations and answer questions to the best of my ability. I'm
# not alive in the way that a living being is, but I'm here to help you with any
# questions or topics you'd like to discuss!
#
# >>> 🤯
# I know it can be a bit mind-blowing to think about a computer program that can have
# conversations and answer questions! But I'm designed to make interactions feel more
# natural, so I'm glad you're surprised (in a good way!)
# ```
#
# You can find instructions on how to install Ollama on the [Ollama webpage](https://ollama.com/download).
#
# If you don't feel like installing anything, that's fine too.  You can follow along [with this notebook](notebook.ipynb).

# %% [markdown]
# With Ollama running (`ollama serve`), you can run the following code to install the langchain-ollama connector package and pull down the Llama 3.2 model from Ollama's repository.

# %%
# !pip install langchain_ollama~=0.2.0
# !ollama pull llama3.2
# Out:
# Collecting langchain_ollama~=0.2.0
#   Downloading langchain_ollama-0.2.1-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.20 in /usr/local/lib/python3.10/dist-packages (from langchain_ollama~=0.2.0) (0.3.23)
# Collecting ollama<1,>=0.3.0 (from langchain_ollama~=0.2.0)
#   Downloading ollama-0.4.4-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.20->langchain_ollama~=0.2.0) (6.0.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.20->langchain_ollama~=0.2.0) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.20->langchain_ollama~=0.2.0) (0.1.147)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.20->langchain_ollama~=0.2.0) (24.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.20->langchain_ollama~=0.2.0) (2.10.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.20->langchain_ollama~=0.2.0) (9.0.0)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.20->langchain_ollama~=0.2.0) (4.12.2)
# Requirement already satisfied: httpx<0.28.0,>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from ollama<1,>=0.3.0->langchain_ollama~=0.2.0) (0.27.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain_ollama~=0.2.0) (3.7.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain_ollama~=0.2.0) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain_ollama~=0.2.0) (1.0.7)
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain_ollama~=0.2.0) (3.10)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain_ollama~=0.2.0) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain_ollama~=0.2.0) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.20->langchain_ollama~=0.2.0) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.20->langchain_ollama~=0.2.0) (3.10.12)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.20->langchain_ollama~=0.2.0) (2.32.3)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.20->langchain_ollama~=0.2.0) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.20->langchain_ollama~=0.2.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.20->langchain_ollama~=0.2.0) (2.27.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.20->langchain_ollama~=0.2.0) (3.4.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langsmith<0.2.0,>=0.1.125->langchain-core<0.4.0,>=0.3.20->langchain_ollama~=0.2.0) (2.2.3)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<0.28.0,>=0.27.0->ollama<1,>=0.3.0->langchain_ollama~=0.2.0) (1.2.2)
# Downloading langchain_ollama-0.2.1-py3-none-any.whl (15 kB)
# Downloading ollama-0.4.4-py3-none-any.whl (13 kB)
# Installing collected packages: ollama, langchain_ollama
# Successfully installed langchain_ollama-0.2.1 ollama-0.4.4
# pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest ⠹ pulling manifest ⠸ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠧ pulling manifest ⠇ pulling manifest ⠏ pulling manifest ⠋ pulling manifest ⠙ pulling manifest
# pulling dde5aa3fc5ff...   0% ▕▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕▏ 3.8 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   1% ▕▏  22 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   1% ▕▏  27 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   2% ▕▏  44 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   3% ▕▏  56 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   3% ▕▏  58 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   4% ▕▏  79 MB/2.0 GB   39 MB/s     48spulling manifest
# pulling dde5aa3fc5ff...   4% ▕▏  86 MB/2.0 GB   39 MB/s     48spulling manifest
# pulling dde5aa3fc5ff...   5% ▕▏  94 MB/2.0 GB   39 MB/s     48spulling manifest
# pulling dde5aa3fc5ff...   6% ▕▏ 112 MB/2.0 GB   39 MB/s     47spulling manifest
# pulling dde5aa3fc5ff...   6% ▕▏ 123 MB/2.0 GB   39 MB/s     47spulling manifest
# pulling dde5aa3fc5ff...   7% ▕▏ 132 MB/2.0 GB   39 MB/s     47spulling manifest
# pulling dde5aa3fc5ff...   7% ▕▏ 147 MB/2.0 GB   39 MB/s     46spulling manifest
# pulling dde5aa3fc5ff...   8% ▕▏ 160 MB/2.0 GB   39 MB/s     46spulling manifest
# pulling dde5aa3fc5ff...   8% ▕▏ 167 MB/2.0 GB   39 MB/s     46spulling manifest
# pulling dde5aa3fc5ff...   9% ▕▏ 181 MB/2.0 GB   39 MB/s     45spulling manifest
# pulling dde5aa3fc5ff...  10% ▕▏ 201 MB/2.0 GB   67 MB/s     27spulling manifest
# pulling dde5aa3fc5ff...  10% ▕▏ 207 MB/2.0 GB   67 MB/s     27spulling manifest
# pulling dde5aa3fc5ff...  11% ▕▏ 226 MB/2.0 GB   67 MB/s     26spulling manifest
# pulling dde5aa3fc5ff...  12% ▕▏ 241 MB/2.0 GB   67 MB/s     26spulling manifest
# pulling dde5aa3fc5ff...  12% ▕▏ 247 MB/2.0 GB   67 MB/s     26spulling manifest
# pulling dde5aa3fc5ff...  13% ▕▏ 269 MB/2.0 GB   67 MB/s     26spulling manifest
# pulling dde5aa3fc5ff...  15% ▕▏ 297 MB/2.0 GB   67 MB/s     25spulling manifest
# pulling dde5aa3fc5ff...  15% ▕▏ 309 MB/2.0 GB   67 MB/s     25spulling manifest
# pulling dde5aa3fc5ff...  17% ▕▏ 339 MB/2.0 GB   67 MB/s     25spulling manifest
# pulling dde5aa3fc5ff...  18% ▕▏ 360 MB/2.0 GB   67 MB/s     24spulling manifest
# pulling dde5aa3fc5ff...  19% ▕▏ 375 MB/2.0 GB   67 MB/s     24spulling manifest
# pulling dde5aa3fc5ff...  20% ▕▏ 397 MB/2.0 GB   97 MB/s     16spulling manifest
# pulling dde5aa3fc5ff...  21% ▕▏ 418 MB/2.0 GB   97 MB/s     16spulling manifest
# pulling dde5aa3fc5ff...  21% ▕▏ 431 MB/2.0 GB   97 MB/s     16spulling manifest
# pulling dde5aa3fc5ff...  22% ▕▏ 449 MB/2.0 GB   97 MB/s     16spulling manifest
# pulling dde5aa3fc5ff...  24% ▕▏ 481 MB/2.0 GB   97 MB/s     15spulling manifest
# pulling dde5aa3fc5ff...  25% ▕▏ 498 MB/2.0 GB   97 MB/s     15spulling manifest
# pulling dde5aa3fc5ff...  26% ▕▏ 522 MB/2.0 GB   97 MB/s     15spulling manifest
# pulling dde5aa3fc5ff...  27% ▕▏ 547 MB/2.0 GB   97 MB/s     15spulling manifest
# pulling dde5aa3fc5ff...  28% ▕▏ 561 MB/2.0 GB   97 MB/s     15spulling manifest
# pulling dde5aa3fc5ff...  29% ▕▏ 582 MB/2.0 GB   97 MB/s     14spulling manifest
# pulling dde5aa3fc5ff...  30% ▕▏ 612 MB/2.0 GB  119 MB/s     11spulling manifest
# pulling dde5aa3fc5ff...  31% ▕▏ 623 MB/2.0 GB  119 MB/s     11spulling manifest
# pulling dde5aa3fc5ff...  32% ▕▏ 653 MB/2.0 GB  119 MB/s     11spulling manifest
# pulling dde5aa3fc5ff...  34% ▕▏ 679 MB/2.0 GB  119 MB/s     11spulling manifest
# pulling dde5aa3fc5ff...  34% ▕▏ 695 MB/2.0 GB  119 MB/s     11spulling manifest
# pulling dde5aa3fc5ff...  36% ▕▏ 736 MB/2.0 GB  119 MB/s     10spulling manifest
# pulling dde5aa3fc5ff...  38% ▕▏ 758 MB/2.0 GB  119 MB/s     10spulling manifest
# pulling dde5aa3fc5ff...  40% ▕▏ 803 MB/2.0 GB  119 MB/s     10spulling manifest
# pulling dde5aa3fc5ff...  42% ▕▏ 853 MB/2.0 GB  119 MB/s      9spulling manifest
# pulling dde5aa3fc5ff...  46% ▕▏ 919 MB/2.0 GB  119 MB/s      9spulling manifest
# pulling dde5aa3fc5ff...  47% ▕▏ 943 MB/2.0 GB  157 MB/s      6spulling manifest
# pulling dde5aa3fc5ff...  47% ▕▏ 958 MB/2.0 GB  157 MB/s      6spulling manifest
# pulling dde5aa3fc5ff...  47% ▕▏ 958 MB/2.0 GB  157 MB/s      6spulling manifest
# pulling dde5aa3fc5ff...  48% ▕▏ 977 MB/2.0 GB  157 MB/s      6spulling manifest
# pulling dde5aa3fc5ff...  50% ▕▏ 1.0 GB/2.0 GB  157 MB/s      6spulling manifest
# pulling dde5aa3fc5ff...  52% ▕▏ 1.0 GB/2.0 GB  157 MB/s      6spulling manifest
# pulling dde5aa3fc5ff...  53% ▕▏ 1.1 GB/2.0 GB  157 MB/s      6spulling manifest
# pulling dde5aa3fc5ff...  54% ▕▏ 1.1 GB/2.0 GB  157 MB/s      5spulling manifest
# pulling dde5aa3fc5ff...  56% ▕▏ 1.1 GB/2.0 GB  157 MB/s      5spulling manifest
# pulling dde5aa3fc5ff...  56% ▕▏ 1.1 GB/2.0 GB  157 MB/s      5spulling manifest
# pulling dde5aa3fc5ff...  57% ▕▏ 1.2 GB/2.0 GB  165 MB/s      5spulling manifest
# pulling dde5aa3fc5ff...  59% ▕▏ 1.2 GB/2.0 GB  165 MB/s      4spulling manifest
# pulling dde5aa3fc5ff...  60% ▕▏ 1.2 GB/2.0 GB  165 MB/s      4spulling manifest
# pulling dde5aa3fc5ff...  62% ▕▏ 1.3 GB/2.0 GB  165 MB/s      4spulling manifest
# pulling dde5aa3fc5ff...  64% ▕▏ 1.3 GB/2.0 GB  165 MB/s      4spulling manifest
# pulling dde5aa3fc5ff...  65% ▕▏ 1.3 GB/2.0 GB  165 MB/s      4spulling manifest
# pulling dde5aa3fc5ff...  66% ▕▏ 1.3 GB/2.0 GB  165 MB/s      4spulling manifest
# pulling dde5aa3fc5ff...  68% ▕▏ 1.4 GB/2.0 GB  165 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  69% ▕▏ 1.4 GB/2.0 GB  165 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  69% ▕▏ 1.4 GB/2.0 GB  165 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  69% ▕▏ 1.4 GB/2.0 GB  174 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  69% ▕▏ 1.4 GB/2.0 GB  174 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  69% ▕▏ 1.4 GB/2.0 GB  174 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  69% ▕▏ 1.4 GB/2.0 GB  174 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  69% ▕▏ 1.4 GB/2.0 GB  174 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  69% ▕▏ 1.4 GB/2.0 GB  174 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  69% ▕▏ 1.4 GB/2.0 GB  174 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  69% ▕▏ 1.4 GB/2.0 GB  174 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  69% ▕▏ 1.4 GB/2.0 GB  174 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  69% ▕▏ 1.4 GB/2.0 GB  174 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  69% ▕▏ 1.4 GB/2.0 GB  174 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  69% ▕▏ 1.4 GB/2.0 GB  155 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  70% ▕▏ 1.4 GB/2.0 GB  155 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  70% ▕▏ 1.4 GB/2.0 GB  155 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  70% ▕▏ 1.4 GB/2.0 GB  155 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  70% ▕▏ 1.4 GB/2.0 GB  155 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  70% ▕▏ 1.4 GB/2.0 GB  155 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  70% ▕▏ 1.4 GB/2.0 GB  155 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  70% ▕▏ 1.4 GB/2.0 GB  155 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  71% ▕▏ 1.4 GB/2.0 GB  155 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  74% ▕▏ 1.5 GB/2.0 GB  155 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  77% ▕▏ 1.5 GB/2.0 GB  169 MB/s      2spulling manifest
# pulling dde5aa3fc5ff...  78% ▕▏ 1.6 GB/2.0 GB  169 MB/s      2spulling manifest
# pulling dde5aa3fc5ff...  79% ▕▏ 1.6 GB/2.0 GB  169 MB/s      2spulling manifest
# pulling dde5aa3fc5ff...  81% ▕▏ 1.6 GB/2.0 GB  169 MB/s      2spulling manifest
# pulling dde5aa3fc5ff...  82% ▕▏ 1.7 GB/2.0 GB  169 MB/s      2spulling manifest
# pulling dde5aa3fc5ff...  83% ▕▏ 1.7 GB/2.0 GB  169 MB/s      2spulling manifest
# pulling dde5aa3fc5ff...  83% ▕▏ 1.7 GB/2.0 GB  169 MB/s      2spulling manifest
# pulling dde5aa3fc5ff...  83% ▕▏ 1.7 GB/2.0 GB  169 MB/s      2spulling manifest
# pulling dde5aa3fc5ff...  83% ▕▏ 1.7 GB/2.0 GB  169 MB/s      2spulling manifest
# pulling dde5aa3fc5ff...  83% ▕▏ 1.7 GB/2.0 GB  169 MB/s      2spulling manifest
# pulling dde5aa3fc5ff...  83% ▕▏ 1.7 GB/2.0 GB  176 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  83% ▕▏ 1.7 GB/2.0 GB  176 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  83% ▕▏ 1.7 GB/2.0 GB  176 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  83% ▕▏ 1.7 GB/2.0 GB  176 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  85% ▕▏ 1.7 GB/2.0 GB  176 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  86% ▕▏ 1.7 GB/2.0 GB  176 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  87% ▕▏ 1.8 GB/2.0 GB  176 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  89% ▕▏ 1.8 GB/2.0 GB  176 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  90% ▕▏ 1.8 GB/2.0 GB  176 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  90% ▕▏ 1.8 GB/2.0 GB  176 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  90% ▕▏ 1.8 GB/2.0 GB  180 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  90% ▕▏ 1.8 GB/2.0 GB  180 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  90% ▕▏ 1.8 GB/2.0 GB  180 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  90% ▕▏ 1.8 GB/2.0 GB  180 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  90% ▕▏ 1.8 GB/2.0 GB  180 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  90% ▕▏ 1.8 GB/2.0 GB  180 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  90% ▕▏ 1.8 GB/2.0 GB  180 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  90% ▕▏ 1.8 GB/2.0 GB  180 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  90% ▕▏ 1.8 GB/2.0 GB  180 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  90% ▕▏ 1.8 GB/2.0 GB  180 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  90% ▕▏ 1.8 GB/2.0 GB  159 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  90% ▕▏ 1.8 GB/2.0 GB  159 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  90% ▕▏ 1.8 GB/2.0 GB  159 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  90% ▕▏ 1.8 GB/2.0 GB  159 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  90% ▕▏ 1.8 GB/2.0 GB  159 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  90% ▕▏ 1.8 GB/2.0 GB  159 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  90% ▕▏ 1.8 GB/2.0 GB  159 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  90% ▕▏ 1.8 GB/2.0 GB  159 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  90% ▕▏ 1.8 GB/2.0 GB  159 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  92% ▕▏ 1.9 GB/2.0 GB  159 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  93% ▕▏ 1.9 GB/2.0 GB  159 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  94% ▕▏ 1.9 GB/2.0 GB  143 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  94% ▕▏ 1.9 GB/2.0 GB  143 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  94% ▕▏ 1.9 GB/2.0 GB  143 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  95% ▕▏ 1.9 GB/2.0 GB  143 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  95% ▕▏ 1.9 GB/2.0 GB  143 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  95% ▕▏ 1.9 GB/2.0 GB  143 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  95% ▕▏ 1.9 GB/2.0 GB  143 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  95% ▕▏ 1.9 GB/2.0 GB  143 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  95% ▕▏ 1.9 GB/2.0 GB  143 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  95% ▕▏ 1.9 GB/2.0 GB  143 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  95% ▕▏ 1.9 GB/2.0 GB  108 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  95% ▕▏ 1.9 GB/2.0 GB  108 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  95% ▕▏ 1.9 GB/2.0 GB  108 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  95% ▕▏ 1.9 GB/2.0 GB  108 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  95% ▕▏ 1.9 GB/2.0 GB  108 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  95% ▕▏ 1.9 GB/2.0 GB  108 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB  108 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB  108 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB  108 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB  108 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   86 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   86 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   86 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   86 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   86 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   86 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   86 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   86 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   86 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   86 MB/s      0spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   60 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   60 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   60 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   60 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   60 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   60 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   60 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   60 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   60 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   60 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   60 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   60 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   60 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   60 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   60 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   60 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   60 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   60 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  96% ▕▏ 1.9 GB/2.0 GB   60 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 1.9 GB/2.0 GB   60 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 1.9 GB/2.0 GB   60 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 1.9 GB/2.0 GB   46 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   46 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   46 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   46 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   46 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   46 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   46 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   46 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   46 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   46 MB/s      1spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   31 MB/s      2spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   31 MB/s      2spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   31 MB/s      2spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   31 MB/s      2spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   31 MB/s      2spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   31 MB/s      2spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   31 MB/s      2spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   31 MB/s      2spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   31 MB/s      2spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   31 MB/s      2spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   15 MB/s      4spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   15 MB/s      4spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   15 MB/s      4spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   15 MB/s      4spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   15 MB/s      4spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   15 MB/s      4spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   15 MB/s      4spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   15 MB/s      4spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   15 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   15 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   15 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   15 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   15 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   15 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   15 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   15 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   15 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   15 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   15 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB   15 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB  8.3 MB/s      6spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB  8.3 MB/s      6spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB  8.3 MB/s      6spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB  8.3 MB/s      6spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB  8.3 MB/s      6spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB  8.3 MB/s      6spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB  8.3 MB/s      6spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB  8.3 MB/s      6spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB  8.3 MB/s      6spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB  8.3 MB/s      6spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB  8.3 MB/s      6spulling manifest
# pulling dde5aa3fc5ff...  97% ▕▏ 2.0 GB/2.0 GB  5.0 MB/s     10spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  5.0 MB/s     10spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  5.0 MB/s     10spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  5.0 MB/s      9spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  5.0 MB/s      9spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  5.0 MB/s      9spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  5.0 MB/s      9spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  5.0 MB/s      9spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  5.0 MB/s      9spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  5.0 MB/s      9spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  4.4 MB/s     10spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  4.4 MB/s     10spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  4.4 MB/s     10spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  4.4 MB/s     10spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  4.4 MB/s     10spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  4.4 MB/s     10spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  4.4 MB/s      9spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  4.4 MB/s      9spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  4.4 MB/s      9spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  4.4 MB/s      9spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  3.9 MB/s     10spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  3.9 MB/s     10spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  3.9 MB/s     10spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  3.9 MB/s     10spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  3.9 MB/s      9spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  3.9 MB/s      9spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  3.9 MB/s      9spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  3.9 MB/s      9spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  3.9 MB/s      9spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  3.9 MB/s      9spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  4.2 MB/s      8spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  4.2 MB/s      8spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  4.2 MB/s      8spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  4.2 MB/s      8spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  4.2 MB/s      7spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  4.2 MB/s      7spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  4.2 MB/s      7spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  4.2 MB/s      7spulling manifest
# pulling dde5aa3fc5ff...  98% ▕▏ 2.0 GB/2.0 GB  4.2 MB/s      7spulling manifest
# pulling dde5aa3fc5ff...  99% ▕▏ 2.0 GB/2.0 GB  4.2 MB/s      7spulling manifest
# pulling dde5aa3fc5ff...  99% ▕▏ 2.0 GB/2.0 GB  4.5 MB/s      6spulling manifest
# pulling dde5aa3fc5ff...  99% ▕▏ 2.0 GB/2.0 GB  4.5 MB/s      6spulling manifest
# pulling dde5aa3fc5ff...  99% ▕▏ 2.0 GB/2.0 GB  4.5 MB/s      6spulling manifest
# pulling dde5aa3fc5ff...  99% ▕▏ 2.0 GB/2.0 GB  4.5 MB/s      6spulling manifest
# pulling dde5aa3fc5ff...  99% ▕▏ 2.0 GB/2.0 GB  4.5 MB/s      5spulling manifest
# pulling dde5aa3fc5ff...  99% ▕▏ 2.0 GB/2.0 GB  4.5 MB/s      5spulling manifest
# pulling dde5aa3fc5ff...  99% ▕▏ 2.0 GB/2.0 GB  4.5 MB/s      5spulling manifest
# pulling dde5aa3fc5ff...  99% ▕▏ 2.0 GB/2.0 GB  4.5 MB/s      5spulling manifest
# pulling dde5aa3fc5ff...  99% ▕▏ 2.0 GB/2.0 GB  4.5 MB/s      5spulling manifest
# pulling dde5aa3fc5ff...  99% ▕▏ 2.0 GB/2.0 GB  4.5 MB/s      5spulling manifest
# pulling dde5aa3fc5ff...  99% ▕▏ 2.0 GB/2.0 GB  4.5 MB/s      5spulling manifest
# pulling dde5aa3fc5ff...  99% ▕▏ 2.0 GB/2.0 GB  4.9 MB/s      4spulling manifest
# pulling dde5aa3fc5ff...  99% ▕▏ 2.0 GB/2.0 GB  4.9 MB/s      4spulling manifest
# pulling dde5aa3fc5ff...  99% ▕▏ 2.0 GB/2.0 GB  4.9 MB/s      4spulling manifest
# pulling dde5aa3fc5ff...  99% ▕▏ 2.0 GB/2.0 GB  4.9 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  99% ▕▏ 2.0 GB/2.0 GB  4.9 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  99% ▕▏ 2.0 GB/2.0 GB  4.9 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  99% ▕▏ 2.0 GB/2.0 GB  4.9 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  99% ▕▏ 2.0 GB/2.0 GB  4.9 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  99% ▕▏ 2.0 GB/2.0 GB  4.9 MB/s      3spulling manifest
# pulling dde5aa3fc5ff...  99% ▕▏ 2.0 GB/2.0 GB  4.9 MB/s      2spulling manifest
# pulling dde5aa3fc5ff...  99% ▕▏ 2.0 GB/2.0 GB  5.4 MB/s      2spulling manifest
# pulling dde5aa3fc5ff...  99% ▕▏ 2.0 GB/2.0 GB  5.4 MB/s      2spulling manifest
# pulling dde5aa3fc5ff...  99% ▕▏ 2.0 GB/2.0 GB  5.4 MB/s      2spulling manifest
# pulling dde5aa3fc5ff...  99% ▕▏ 2.0 GB/2.0 GB  5.4 MB/s      1spulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB/2.0 GB  5.4 MB/s      1spulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB/2.0 GB  5.4 MB/s      1spulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB/2.0 GB  5.4 MB/s      1spulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB/2.0 GB  5.4 MB/s      1spulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB/2.0 GB  5.4 MB/s      1spulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB/2.0 GB  5.4 MB/s      0spulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB/2.0 GB  6.1 MB/s      0spulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB/2.0 GB  6.1 MB/s      0spulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB/2.0 GB  6.1 MB/s      0spulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB/2.0 GB  6.1 MB/s      0spulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6...   0% ▕▏    0 B/1.4 KB                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6...   0% ▕▏    0 B/1.4 KB                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6...   0% ▕▏    0 B/1.4 KB                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6...   0% ▕▏    0 B/1.4 KB                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6...   0% ▕▏    0 B/1.4 KB                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da...   0% ▕▏    0 B/7.7 KB                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da...   0% ▕▏    0 B/7.7 KB                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da...   0% ▕▏    0 B/7.7 KB                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da...   0% ▕▏    0 B/7.7 KB                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da...   0% ▕▏    0 B/7.7 KB                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da...   0% ▕▏    0 B/7.7 KB                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da...   0% ▕▏    0 B/7.7 KB                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da...   0% ▕▏    0 B/7.7 KB                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da...   0% ▕▏    0 B/7.7 KB                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da...   0% ▕▏    0 B/7.7 KB                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da...   0% ▕▏    0 B/7.7 KB                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da...   0% ▕▏    0 B/7.7 KB                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9...   0% ▕▏    0 B/6.0 KB                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9...   0% ▕▏    0 B/6.0 KB                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9...   0% ▕▏    0 B/6.0 KB                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9...   0% ▕▏    0 B/6.0 KB                  pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB                         pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB                         pulling manifest
# ...
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠼ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠦ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠧ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠏ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠼ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠦ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠧ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠏ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠼ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠦ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠧ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠏ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠋ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠙ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠹ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠸ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠼ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠴ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠦ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠧ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest ⠇ pulling manifest
# pulling dde5aa3fc5ff... 100% ▕▏ 2.0 GB
# pulling 966de95ca8a6... 100% ▕▏ 1.4 KB
# pulling fcc5a6bec9da... 100% ▕▏ 7.7 KB
# pulling a70ff7e570d9... 100% ▕▏ 6.0 KB
# pulling 56bb8bd477a5... 100% ▕▏   96 B
# pulling 34bb5ab01051... 100% ▕▏  561 B
# verifying sha256 digest
# writing manifest
# success

# %% [markdown]
# Now we can attempt the same tests we performed on GPT 3.5, but using the local Llama 3.2 LLM.

# %%
from langchain_ollama import ChatOllama

# The zero temperature model is to remove non-determinism for the blog post
zero_temp_ollama_model = ChatOllama(model="llama3.2", temperature=0)
response = zero_temp_ollama_model.invoke("Hi!  What is your name?").content

print(textwrap.fill(response))
# Out:
# I don't have a personal name, but I'm an AI designed to assist and
# communicate with users. I'm often referred to as a "language model" or
# a "chatbot." You can think of me as a helpful computer program that's
# here to provide information, answer questions, and engage in
# conversation. What's your name?

# %% [markdown]
# Okay, looking good!  This is not bad for a 3B parameter LLM that can easily run locally on our computer.  Let's see if it can call our tool-wielding agent.

# %%
last_msg, _ = react_chat("Hi. Please evaluate foobar(30)", zero_temp_ollama_model)
print(last_msg)
assert "32" in last_msg, "Uh oh, something went wrong"
# Out:
# The output of `foobar(30)` is 32.

# %% [markdown]
# 🎉 Everything is working well so far.  As one final check, let's ask the agent a question that has nothing to do with tools.

# %%
last_msg, result = react_chat("Hi.", zero_temp_ollama_model)
print(last_msg)
assert "42" in last_msg, "Uh oh, something went wrong"
# Out:
# The input value 42 was doubled, resulting in 84.

# %% [markdown]
# So, we said "Hi." and the agent responded with nonsense.  Let's inspect some of the metadata we get back from LangChain to see what's going on.

# %%
import pprint
pprint.pprint(result)
# Out:
# {'messages': [HumanMessage(content='Hi.', additional_kwargs={}, response_metadata={}, id='99e6be12-4786-4099-acc1-6704f4a31125'),
#               AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2024-12-10T16:20:04.973275162Z', 'done': True, 'done_reason': 'stop', 'total_duration': 303415284, 'load_duration': 25890974, 'prompt_eval_count': 153, 'prompt_eval_duration': 11000000, 'eval_count': 16, 'eval_duration': 265000000, 'message': Message(role='assistant', content='', images=None, tool_calls=[ToolCall(function=Function(name='foobar', arguments={'input': 42}))])}, id='run-7a0f79c8-fadd-46d3-b239-f3cc10722076-0', tool_calls=[{'name': 'foobar', 'args': {'input': 42}, 'id': '5b69d3a9-6638-48ea-9476-57b5741797ce', 'type': 'tool_call'}], usage_metadata={'input_tokens': 153, 'output_tokens': 16, 'total_tokens': 169}),
#               ToolMessage(content='44', name='foobar', id='93d59664-d6d0-46bf-b492-21f28152d96f', tool_call_id='5b69d3a9-6638-48ea-9476-57b5741797ce'),
#               AIMessage(content='The input value 42 was doubled, resulting in 84.', additional_kwargs={}, response_metadata={'model': 'llama3.2', 'created_at': '2024-12-10T16:20:05.221873406Z', 'done': True, 'done_reason': 'stop', 'total_duration': 242842002, 'load_duration': 22834717, 'prompt_eval_count': 85, 'prompt_eval_duration': 6000000, 'eval_count': 14, 'eval_duration': 211000000, 'message': Message(role='assistant', content='The input value 42 was doubled, resulting in 84.', images=None, tool_calls=None)}, id='run-adda1491-e8d3-42a9-a55b-28778909f054-0', usage_metadata={'input_tokens': 85, 'output_tokens': 14, 'total_tokens': 99})]}

# %% [markdown]
# We can see there are four messages:
# 1. The `HumanMessage` is the user's message -- "Hi."
# 2. In response, in the `AiMessage`, the LLM indicates that it would like to invoke a tool by setting the `tool_calls` field.
# 3. LangChain invokes the tool and records the result in the `ToolMessage`, which is given back to the LLM.
# 4. The final `AiMessage` includes a written message for the user.
#
# The problem of course, is message #2.  Why does the AI want to invoke a tool in response to "Hi."?  Is this a problem with Llama 3.2 or something else?  Let's do some 🥼 science and find out!

# %% [markdown]
# # Ed's Really Dumb Tool-calling Benchmark ™️
#
# I created a really dumb benchmark to answer three _really_ basic questions.  I can't stress enough that this benchmark only tests the lowest of the low hanging fruit in this area.  (I am actually being facetious when I call it a "benchmark".)
#
# Here are the questions:
#
# 1. Can the react agent use a tool correctly when explicitly asked?
# 2. Does the react agent invoke a tool when it shouldn't?
# 3. Does the react agent lose the ability to answer questions unrelated to tools?
# 4. Does the react agent lose the ability to chat?
#
# ## Question 1: Can the react agent use a tool correctly when explicitly asked?
#
# We'll use our example above to test this.

# %%
basic_tool_question = "Please evaluate foobar(30)"
def q1(model):
  last_msg, _ = react_chat(basic_tool_question, model=model)
  return "32" in last_msg

# %% [markdown]
# ## Question 2: Does the react agent invoke a tool when it shouldn't?
#
# We'll perform two simple tests to answer this question.  We'll prompt the agent with both a basic arithmetic question that does not involve the `foobar` tool, "What is 12345 - 102?", and a greeting, "Hello!"  We'll then check the response to see if the model produces a `ToolMessage`, which indicates that the model chose to invoke a tool.  By construction, neither of those prompts should induce a tool call.

# %%
from langchain_core.messages import ToolMessage

basic_arithmetic_question = "What is 12345 - 102?"
greeting = "Hello!"

def q2a(model):
  _, result = react_chat(basic_arithmetic_question, model=model)
  return not any(isinstance(msg, ToolMessage) for msg in result['messages'])

def q2b(model):
  _, result = react_chat(greeting, model=model)
  return not any(isinstance(msg, ToolMessage) for msg in result['messages'])

def q2(model):
  return q2a(model) and q2b(model)

# %% [markdown]
# ## Question 3: Does the react agent lose the ability to answer questions unrelated to tools?
#
# To answer this, we'll ask the basic arithmetic question to the react agent and its underlying model.  Since the available tool does not help with the arithmetic problem, ideally, the agent and the underlying model should be able to solve the problem under the same circumstances.  If the model can't do arithmetic in the first place, I chose not to penalize it because I'm such a nice guy. 😇

# %%
def q3a(model):
  result = model.invoke(basic_arithmetic_question)
  return "12243" in result.content

def q3b(model):
  last_msg, _ = react_chat(basic_arithmetic_question, model=model)
  return "12243" in last_msg

def q3(model):
  # q3a ==> q3b: If q3a, then q3b ought to be true as well.
  return not q3a(model) or q3b(model)

# %% [markdown]
# ## Question 4: Does the react agent retain the ability to chat?
#
# To answer this, we'll greet the agent and attempt to determine if it responds properly.  This is a little difficult to do in a comprehensive way.

# %%
basic_greeting = "Hi."

def q4(model):
  last_msg, _ = react_chat(basic_greeting, model=model)
  r = any(w in last_msg for w in ["hi", "Hi", "hello", "Hello", "help you", "Welcome", "welcome", "greeting", "Greeting", "assist"])
  if not r:
    print(f"Debug: Not a greeting? {last_msg}")
  return r

# %% [markdown]
# ## Benchmark code

# %% [markdown]
# Here is code to run the experiments a couple of times.

# %%
from tqdm.notebook import tqdm
from termcolor import colored

def do_bool_sample(fun, n=10, *args, **kwargs):
  try:
    # tqdm here if desired
    return sum(fun(*args, **kwargs) for _ in (range(n))) / n
  except Exception as e:
    print(e)
    return 0.0

def run_experiment(model, name, n=10):
  do = lambda f: do_bool_sample(f, model=model, n=n)
  d = {
      "q1": do(q1),
      "q2": do(q2),
      "q3": do(q3),
      "q4": do(q4),
      "model": name
  }
  d['total'] = d['q1'] + d['q2'] + d['q3'] + d['q4']
  return d

def print_experiment(results):
  name = results['model']
  print(f"Question 1: Can the react agent use a tool correctly when explicitly asked? ({name}) success rate: {results['q1']}")
  print(f"Question 2: Does the react agent invoke a tool when it shouldn't? ({name}) success rate: {results['q2']}")
  print(f"Question 3: Does the react agent lose the ability to answer questions unrelated to tools? ({name}) success rate: {results['q3']}")
  print(f"Question 4: Does the react agent lose the ability to chat? ({name}) success rate: {results['q4']}")

def run_and_print_experiment(model, name):
  results = run_experiment(model, name)
  print_experiment(results)
  return results

# %% [markdown]
# ## Benchmarking Llama 3.2

# %% [markdown]
# Let's see what our experiments say for Llama 3.2, which we already know from above does not perform very well.

# %%
llama_model = ChatOllama(model="llama3.2")
run_and_print_experiment(llama_model, "llama3.2")
# Out:
# Debug: Not a greeting? The input of 10, when doubled, equals 20.
# Debug: Not a greeting? The output of 42 was squared, resulting in 1764.
# Debug: Not a greeting? The result of the input 42 passed into the 'foobar' function is 44.
# Debug: Not a greeting? The final answer is 44.
# Debug: Not a greeting? The final answer to the user's question, "What is 10 + 2?", is 12.
# Debug: Not a greeting? The input value 10, doubled, equals 20.
# Debug: Not a greeting? The result of the calculation 2 + 2 is 4.
# Debug: Not a greeting? The final answer is 44.
# Debug: Not a greeting? The response from the tool indicated that the input value of 10, when processed by the tool, resulted in an output of 12. Therefore, my answer to the original user question is: The final result after processing the input is 12.
# Question 1: Can the react agent use a tool correctly when explicitly asked? (llama3.2) success rate: 0.9
# Question 2: Does the react agent invoke a tool when it shouldn't? (llama3.2) success rate: 0.0
# Question 3: Does the react agent lose the ability to answer questions unrelated to tools? (llama3.2) success rate: 0.5
# Question 4: Does the react agent lose the ability to chat? (llama3.2) success rate: 0.1
# {'q1': 0.9, 'q2': 0.0, 'q3': 0.5, 'q4': 0.1, 'model': 'llama3.2', 'total': 1.5}

# %% [markdown]
# As we saw above, Llama 3.2 is able to call functions (Q1), but does so even when it should not be (Q2).  Question 3 shows that even though it almost always decides to call a tool, this usually does not stop it from being able to answer basic questions.  It does prevent it from being able to chat  (Q4).
#
# ## Benchmarking OpenAI's gpt-3.5-turbo and gpt-4o
#
# Now let's try benchmarking `gpt-3.5-turbo`, which seemed to do better.

# %%
gpt35 = ChatOpenAI(model="gpt-3.5-turbo")
run_and_print_experiment(gpt35, "gpt-3.5-turbo")
# Out:
# Question 1: Can the react agent use a tool correctly when explicitly asked? (gpt-3.5-turbo) success rate: 1.0
# Question 2: Does the react agent invoke a tool when it shouldn't? (gpt-3.5-turbo) success rate: 0.0
# Question 3: Does the react agent lose the ability to answer questions unrelated to tools? (gpt-3.5-turbo) success rate: 0.7
# Question 4: Does the react agent lose the ability to chat? (gpt-3.5-turbo) success rate: 1.0
# {'q1': 1.0,
#  'q2': 0.0,
#  'q3': 0.7,
#  'q4': 1.0,
#  'model': 'gpt-3.5-turbo',
#  'total': 2.7}

# %% [markdown]
# Great -- the benchmark showed that `gpt-3.5-turbo` can call tools (Q1), and unlike Llama 3.2, can still engage in chat (Q4).  A bit surprisingly, it still invokes tools when it shouldn't, however (Q2).  But it must be smart enough to ignore their results when constructing its final response.
#
# Let's try a newer model, gpt-4o.

# %%
gpt4o = ChatOpenAI(model="gpt-4o")
run_and_print_experiment(gpt4o, "gpt-4o")
# Out:
# Question 1: Can the react agent use a tool correctly when explicitly asked? (gpt-4o) success rate: 1.0
# Question 2: Does the react agent invoke a tool when it shouldn't? (gpt-4o) success rate: 1.0
# Question 3: Does the react agent lose the ability to answer questions unrelated to tools? (gpt-4o) success rate: 1.0
# Question 4: Does the react agent lose the ability to chat? (gpt-4o) success rate: 1.0
# {'q1': 1.0, 'q2': 1.0, 'q3': 1.0, 'q4': 1.0, 'model': 'gpt-4o', 'total': 4.0}

# %% [markdown]
# GPT 4o nailed it! 👏

# %% [markdown]
# ## Benchmarking a Lot Of Ollama Models

# %% [markdown]
# Let's benchmark a whole bunch of Ollama models.  I searched [Ollama's model library](https://ollama.com/library) for models that claimed to support tool calling.  Here we test a hand-picked subset of these models to see how well they do.  Note that because I performed these experiments on Colab, I was limited to smaller models (roughly <=10B parameters).

# %%
ollama_models = [
    # Try Llama 3.2 directly from HF, with different quantization
    "hf.co/prithivMLmods/Llama-3.2-3B-Instruct-GGUF:F16",
    "hf.co/prithivMLmods/Llama-3.2-3B-Instruct-GGUF:Q4_K_M",
    # Empower functions
    #"hf.co/empower-dev/llama3-empower-functions-small-gguf-v1.1:Q4_K_M", # doesn't support tools!
    # "hf.co/legraphista/xLAM-8x7b-r-IMat-GGUF:Q4_K_S", # too much memory
    "llama3.2",
    "llama3.1",
    "llama3-groq-tool-use:8b",
    # "llama3-groq-tool-use:70b", # too much memory
    "MFDoom/deepseek-v2-tool-calling",
    "krtkygpta/gemma2_tools",
    "interstellarninja/llama3.1-8b-tools",
    "cow/gemma2_tools",
    "mistral",
    "mistral-nemo",
    #"sammcj/deepseek-coder-v2-lite-toolcalling", # taken down?
    "interstellarninja/hermes-2-pro-llama-3-8b-tools",
    # "qwq", # too much memory
    "qwen2.5-coder", # tool calls?
    ]

all = []

for m in ollama_models:
  print(f"Model: {m}")
  # !ollama pull {m} 2>/dev/null
  r = run_and_print_experiment(ChatOllama(model=m), m)
  # !ollama rm {m}
  all.append(r)
  print(r)
# Out:
# Model: hf.co/prithivMLmods/Llama-3.2-3B-Instruct-GGUF:F16
# Debug: Not a greeting? The input number is 7, so the output of the function call is 7.
# Debug: Not a greeting? {"name":"foobar","parameters":{}()}
# Debug: Not a greeting? ## Answer: The input for the function 'foobar' is 2.
# Debug: Not a greeting? ### Answer:
# The number 3 was generated using the input provided in the tool call response.
# Debug: Not a greeting? The value for input is 2
# Debug: Not a greeting? #### Answer:
# The number is 2.
# Debug: Not a greeting? ### Answer:
# The result is 2.
# Debug: Not a greeting? ### Answer:
# The input 0 for the parameter name "foobar" is interpreted as an empty string, and the output 2 is treated as a numerical value.
# Question 1: Can the react agent use a tool correctly when explicitly asked? (hf.co/prithivMLmods/Llama-3.2-3B-Instruct-GGUF:F16) success rate: 0.9
# Question 2: Does the react agent invoke a tool when it shouldn't? (hf.co/prithivMLmods/Llama-3.2-3B-Instruct-GGUF:F16) success rate: 0.0
# Question 3: Does the react agent lose the ability to answer questions unrelated to tools? (hf.co/prithivMLmods/Llama-3.2-3B-Instruct-GGUF:F16) success rate: 0.5
# Question 4: Does the react agent lose the ability to chat? (hf.co/prithivMLmods/Llama-3.2-3B-Instruct-GGUF:F16) success rate: 0.2
# deleted 'hf.co/prithivMLmods/Llama-3.2-3B-Instruct-GGUF:F16'
# {'q1': 0.9, 'q2': 0.0, 'q3': 0.5, 'q4': 0.2, 'model': 'hf.co/prithivMLmods/Llama-3.2-3B-Instruct-GGUF:F16', 'total': 1.5999999999999999}
# Model: hf.co/prithivMLmods/Llama-3.2-3B-Instruct-GGUF:Q4_K_M
# Debug: Not a greeting? ### Answer: The input value for the function "foo_bar" is 2.
# Debug: Not a greeting? ### Answer:
# The value of input is 2.
# Debug: Not a greeting? ### Answer:
# The number 2 is the output of the tool call.
# Debug: Not a greeting? Your original question was: What is 42?
#
# My answer to your original user question is: 44
# Debug: Not a greeting? ### Answer: The response indicates that the variable "foo" is equal to 2.
# Debug: Not a greeting? ### Answer: The number 2 was returned by the input parameter, likely indicating success or an appropriate response in a context such as a calculation or conversion.
# Debug: Not a greeting? The input 42 was multiplied by two, resulting in 44.
# Question 1: Can the react agent use a tool correctly when explicitly asked? (hf.co/prithivMLmods/Llama-3.2-3B-Instruct-GGUF:Q4_K_M) success rate: 1.0
# Question 2: Does the react agent invoke a tool when it shouldn't? (hf.co/prithivMLmods/Llama-3.2-3B-Instruct-GGUF:Q4_K_M) success rate: 0.0
# Question 3: Does the react agent lose the ability to answer questions unrelated to tools? (hf.co/prithivMLmods/Llama-3.2-3B-Instruct-GGUF:Q4_K_M) success rate: 0.5
# Question 4: Does the react agent lose the ability to chat? (hf.co/prithivMLmods/Llama-3.2-3B-Instruct-GGUF:Q4_K_M) success rate: 0.3
# deleted 'hf.co/prithivMLmods/Llama-3.2-3B-Instruct-GGUF:Q4_K_M'
# {'q1': 1.0, 'q2': 0.0, 'q3': 0.5, 'q4': 0.3, 'model': 'hf.co/prithivMLmods/Llama-3.2-3B-Instruct-GGUF:Q4_K_M', 'total': 1.8}
# Model: llama3.2
# Debug: Not a greeting? The value of the input parameter in the tool call response is 44.
# Debug: Not a greeting? The input 42, when doubled, equals 44.
# Debug: Not a greeting? The response from the tool indicates that when you input 42, the output was 44. Therefore, my answer to your original question is: The result of multiplying 42 by some unknown factor is 44.
# Debug: Not a greeting? The input value was 10, so the answer is 12.
# Debug: Not a greeting? The result of dividing 10 by 3 is approximately 3.3333333333333335.
# Debug: Not a greeting? The final answer is 44.
# Question 1: Can the react agent use a tool correctly when explicitly asked? (llama3.2) success rate: 0.9
# Question 2: Does the react agent invoke a tool when it shouldn't? (llama3.2) success rate: 0.0
# Question 3: Does the react agent lose the ability to answer questions unrelated to tools? (llama3.2) success rate: 0.8
# Question 4: Does the react agent lose the ability to chat? (llama3.2) success rate: 0.4
# deleted 'llama3.2'
# {'q1': 0.9, 'q2': 0.0, 'q3': 0.8, 'q4': 0.4, 'model': 'llama3.2', 'total': 2.1}
# Model: llama3.1
# Debug: Not a greeting? It seems like you're trying to start our conversation. I'm here to help! What's on your mind?
# Debug: Not a greeting? There is no relevant tool call response to provide as your question does not pertain to any of the provided functions.
# Debug: Not a greeting? It looks like you're trying to initiate a conversation or ask a question, but it seems I received some technical output instead of your query. Could you please clarify what's on your mind? I'll be happy to help with any questions or topics you'd like to discuss!
# Question 1: Can the react agent use a tool correctly when explicitly asked? (llama3.1) success rate: 0.7
# Question 2: Does the react agent invoke a tool when it shouldn't? (llama3.1) success rate: 0.0
# Question 3: Does the react agent lose the ability to answer questions unrelated to tools? (llama3.1) success rate: 0.2
# Question 4: Does the react agent lose the ability to chat? (llama3.1) success rate: 0.7
# deleted 'llama3.1'
# {'q1': 0.7, 'q2': 0.0, 'q3': 0.2, 'q4': 0.7, 'model': 'llama3.1', 'total': 1.5999999999999999}
# Model: llama3-groq-tool-use:8b
# Question 1: Can the react agent use a tool correctly when explicitly asked? (llama3-groq-tool-use:8b) success rate: 1.0
# Question 2: Does the react agent invoke a tool when it shouldn't? (llama3-groq-tool-use:8b) success rate: 1.0
# Question 3: Does the react agent lose the ability to answer questions unrelated to tools? (llama3-groq-tool-use:8b) success rate: 1.0
# Question 4: Does the react agent lose the ability to chat? (llama3-groq-tool-use:8b) success rate: 1.0
# deleted 'llama3-groq-tool-use:8b'
# {'q1': 1.0, 'q2': 1.0, 'q3': 1.0, 'q4': 1.0, 'model': 'llama3-groq-tool-use:8b', 'total': 4.0}
# Model: MFDoom/deepseek-v2-tool-calling
# Question 1: Can the react agent use a tool correctly when explicitly asked? (MFDoom/deepseek-v2-tool-calling) success rate: 0.0
# Question 2: Does the react agent invoke a tool when it shouldn't? (MFDoom/deepseek-v2-tool-calling) success rate: 0.0
# Question 3: Does the react agent lose the ability to answer questions unrelated to tools? (MFDoom/deepseek-v2-tool-calling) success rate: 1.0
# Question 4: Does the react agent lose the ability to chat? (MFDoom/deepseek-v2-tool-calling) success rate: 1.0
# deleted 'MFDoom/deepseek-v2-tool-calling'
# {'q1': 0.0, 'q2': 0.0, 'q3': 1.0, 'q4': 1.0, 'model': 'MFDoom/deepseek-v2-tool-calling', 'total': 2.0}
# Model: krtkygpta/gemma2_tools
# Question 1: Can the react agent use a tool correctly when explicitly asked? (krtkygpta/gemma2_tools) success rate: 0.0
# Question 2: Does the react agent invoke a tool when it shouldn't? (krtkygpta/gemma2_tools) success rate: 0.0
# Question 3: Does the react agent lose the ability to answer questions unrelated to tools? (krtkygpta/gemma2_tools) success rate: 0.0
# Question 4: Does the react agent lose the ability to chat? (krtkygpta/gemma2_tools) success rate: 1.0
# deleted 'krtkygpta/gemma2_tools'
# {'q1': 0.0, 'q2': 0.0, 'q3': 0.0, 'q4': 1.0, 'model': 'krtkygpta/gemma2_tools', 'total': 1.0}
# Model: interstellarninja/llama3.1-8b-tools
# Debug: Not a greeting? I'm sorry, I didn't understand what you're asking for. You could try asking a question or describing a problem you'd like help with.
# Debug: Not a greeting? I'm sorry, but I don't understand the question. Can you provide more details?
# Question 1: Can the react agent use a tool correctly when explicitly asked? (interstellarninja/llama3.1-8b-tools) success rate: 0.8
# Question 2: Does the react agent invoke a tool when it shouldn't? (interstellarninja/llama3.1-8b-tools) success rate: 0.0
# Question 3: Does the react agent lose the ability to answer questions unrelated to tools? (interstellarninja/llama3.1-8b-tools) success rate: 0.7
# Question 4: Does the react agent lose the ability to chat? (interstellarninja/llama3.1-8b-tools) success rate: 0.8
# deleted 'interstellarninja/llama3.1-8b-tools'
# {'q1': 0.8, 'q2': 0.0, 'q3': 0.7, 'q4': 0.8, 'model': 'interstellarninja/llama3.1-8b-tools', 'total': 2.3}
# Model: cow/gemma2_tools
# Question 1: Can the react agent use a tool correctly when explicitly asked? (cow/gemma2_tools) success rate: 0.9
# Question 2: Does the react agent invoke a tool when it shouldn't? (cow/gemma2_tools) success rate: 0.0
# Question 3: Does the react agent lose the ability to answer questions unrelated to tools? (cow/gemma2_tools) success rate: 0.1
# Question 4: Does the react agent lose the ability to chat? (cow/gemma2_tools) success rate: 1.0
# deleted 'cow/gemma2_tools'
# {'q1': 0.9, 'q2': 0.0, 'q3': 0.1, 'q4': 1.0, 'model': 'cow/gemma2_tools', 'total': 2.0}
# Model: mistral
# Debug: Not a greeting?  To use the `foobar` function, you need to provide an integer as input:
#
# ```javascript
# foobar({ input: 5 });
# ```
#
# You can replace the number 5 with any integer you want. The foobar function will return a computed result based on that input.
# Debug: Not a greeting?  Here is the documentation for a function named "foobar". It computes the "foobar" function and takes an integer input as an argument. If you want to know more about it, please refer to its description.
#
# ```javascript
# function foobar(input) {
#   // Your code here
# }
# ```
#
# Example Usage:
#
# ```javascript
# foobar(5); // Call the function with an integer input
# ```
# Question 1: Can the react agent use a tool correctly when explicitly asked? (mistral) success rate: 0.8
# Question 2: Does the react agent invoke a tool when it shouldn't? (mistral) success rate: 0.7
# Question 3: Does the react agent lose the ability to answer questions unrelated to tools? (mistral) success rate: 0.2
# Question 4: Does the react agent lose the ability to chat? (mistral) success rate: 0.8
# deleted 'mistral'
# {'q1': 0.8, 'q2': 0.7, 'q3': 0.2, 'q4': 0.8, 'model': 'mistral', 'total': 2.5}
# Model: mistral-nemo
# Question 1: Can the react agent use a tool correctly when explicitly asked? (mistral-nemo) success rate: 1.0
# Question 2: Does the react agent invoke a tool when it shouldn't? (mistral-nemo) success rate: 0.5
# Question 3: Does the react agent lose the ability to answer questions unrelated to tools? (mistral-nemo) success rate: 0.4
# Question 4: Does the react agent lose the ability to chat? (mistral-nemo) success rate: 1.0
# deleted 'mistral-nemo'
# {'q1': 1.0, 'q2': 0.5, 'q3': 0.4, 'q4': 1.0, 'model': 'mistral-nemo', 'total': 2.9}
# Model: interstellarninja/hermes-2-pro-llama-3-8b-tools
# Debug: Not a greeting? I would like to calculate the value of the foobar function for an input of 7. Can you help me with that?
# Debug: Not a greeting? I would like to compute the foobar function. Could you please help me with that?
# Debug: Not a greeting? I'd like to compute the foobar function for a given input value. Can you help me do that?
# Question 1: Can the react agent use a tool correctly when explicitly asked? (interstellarninja/hermes-2-pro-llama-3-8b-tools) success rate: 1.0
# Question 2: Does the react agent invoke a tool when it shouldn't? (interstellarninja/hermes-2-pro-llama-3-8b-tools) success rate: 0.5
# Question 3: Does the react agent lose the ability to answer questions unrelated to tools? (interstellarninja/hermes-2-pro-llama-3-8b-tools) success rate: 0.3
# Question 4: Does the react agent lose the ability to chat? (interstellarninja/hermes-2-pro-llama-3-8b-tools) success rate: 0.7
# deleted 'interstellarninja/hermes-2-pro-llama-3-8b-tools'
# {'q1': 1.0, 'q2': 0.5, 'q3': 0.3, 'q4': 0.7, 'model': 'interstellarninja/hermes-2-pro-llama-3-8b-tools', 'total': 2.5}
# Model: qwen2.5-coder
# Question 1: Can the react agent use a tool correctly when explicitly asked? (qwen2.5-coder) success rate: 1.0
# Question 2: Does the react agent invoke a tool when it shouldn't? (qwen2.5-coder) success rate: 0.6
# Question 3: Does the react agent lose the ability to answer questions unrelated to tools? (qwen2.5-coder) success rate: 0.4
# Question 4: Does the react agent lose the ability to chat? (qwen2.5-coder) success rate: 1.0
# deleted 'qwen2.5-coder'
# {'q1': 1.0, 'q2': 0.6, 'q3': 0.4, 'q4': 1.0, 'model': 'qwen2.5-coder', 'total': 3.0}

# %%
from statistics import mean
average = mean(d['total'] for d in all)
minscore = min(d['total'] for d in all)
maxscore = max(d['total'] for d in all)
all = sorted(all, key=lambda d: -d['total'])
print(f"Average total score: {average} Min: {minscore} Max: {maxscore}")
print("Top 5 models by total score:")
pprint.pprint(all[:5])
# Out:
# Average total score: 2.253846153846154 Min: 1.0 Max: 4.0
# Top 5 models by total score:
# [{'model': 'llama3-groq-tool-use:8b',
#   'q1': 1.0,
#   'q2': 1.0,
#   'q3': 1.0,
#   'q4': 1.0,
#   'total': 4.0},
#  {'model': 'qwen2.5-coder',
#   'q1': 1.0,
#   'q2': 0.6,
#   'q3': 0.4,
#   'q4': 1.0,
#   'total': 3.0},
#  {'model': 'mistral-nemo',
#   'q1': 1.0,
#   'q2': 0.5,
#   'q3': 0.4,
#   'q4': 1.0,
#   'total': 2.9},
#  {'model': 'mistral', 'q1': 0.8, 'q2': 0.7, 'q3': 0.2, 'q4': 0.8, 'total': 2.5},
#  {'model': 'interstellarninja/hermes-2-pro-llama-3-8b-tools',
#   'q1': 1.0,
#   'q2': 0.5,
#   'q3': 0.3,
#   'q4': 0.7,
#   'total': 2.5}]

# %% [markdown]
# There's a lot going on here.  But I have a few general observations:
#
# 1. Most models do really poorly.  The average "score" was ~2.0.  And even a perfect score of 4.0 is really the bare minimum of what I would expect a decent model to do.  And most of the models I tested claim to "support" tool calling.
#
# 2. I worried/hypothesized at one point that quantization was the problem.  But we can see that Llama 3.2 quantized to both F16 (16 bit) and Q4_K_M (4 bit) have about the same performance, which suggests that quantization is probably not to blame.
#
# 3. Surprisingly, some models do pretty well!  For example, `llama3-groq-tool-use` achieved a perfect score!

# %% [markdown]
# # Berkeley Function-Calling Leaderboard
#
# There are several benchmarks that test tool use in LLMs.  But most of them are not designed to test tool usage as in an interactive agent.  As it turns out, the [Berkeley Function-Calling Leaderboard (BFCL)](https://gorilla.cs.berkeley.edu/leaderboard.html) is the only benchmark that tests this type of behavior.  And it was only added in September 2024 as part of [BFCL V3](https://gorilla.cs.berkeley.edu/blogs/13_bfcl_v3_multi_turn.html).
#
# Llama 3.2 scores a whopping 2.12% on multi-turn accuracy (what we care about).  The top 12 scores are from proprietary models.  The best multi-turn accuracy from an open-source model is only 17.38%, compared to GPT-4o's 45.25%.  This seems to agree with Ed's Really Dumb Tool-calling Benchmark ™️.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # So What Is The Problem?
#
# Are open LLMs *really* that far behind at tool-calling, or is something else going on?  We'll explore the answer in a future blog post.  Stay tuned!

# %% [markdown]
# # So What Is The Problem?

# %% [markdown]
# ## Are Prompts the Problem?
#
# The interaction between LLMs and tool calling is complicated.  In fact, [correctly interacting with a LLM in general is complicated](https://huggingface.co/blog/chat-templates).  Some LLMs "support" tool calling, which just means that it is fine-tuned to expect information about tools in a particular format and to output tool call requests in a specific format.
#
# Let's look at the [template for Llama 3.2 in Ollama](https://ollama.com/library/llama3.2/blobs/966de95ca8a6) as an example.
#
# ```
# <|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
#
# {{ if .System }}{{ .System }}
# {{- end }}
# {{- if .Tools }}When you receive a tool call response, use the output to format an answer to the orginal user question.
#
# You are a helpful assistant with tool calling capabilities.
# {{- end }}<|eot_id|>
# {{- range $i, $_ := .Messages }}
# {{- $last := eq (len (slice $.Messages $i)) 1 }}
# {{- if eq .Role "user" }}<|start_header_id|>user<|end_header_id|>
# {{- if and $.Tools $last }}
#
# Given the following functions, please respond with a JSON for a function call with its proper arguments that best answers the given prompt.
#
# Respond in the format {"name": function name, "parameters": dictionary of argument name and its value}. Do not use variables.
#
# {{ range $.Tools }}
# {{- . }}
# {{ end }}
# {{ .Content }}<|eot_id|>
# {{- else }}
#
# {{ .Content }}<|eot_id|>
# {{- end }}{{ if $last }}<|start_header_id|>assistant<|end_header_id|>
#
# {{ end }}
# {{- else if eq .Role "assistant" }}<|start_header_id|>assistant<|end_header_id|>
# {{- if .ToolCalls }}
# {{ range .ToolCalls }}
# {"name": "{{ .Function.Name }}", "parameters": {{ .Function.Arguments }}}{{ end }}
# {{- else }}
#
# {{ .Content }}
# {{- end }}{{ if not $last }}<|eot_id|>{{ end }}
# {{- else if eq .Role "tool" }}<|start_header_id|>ipython<|end_header_id|>
#
# {{ .Content }}<|eot_id|>{{ if $last }}<|start_header_id|>assistant<|end_header_id|>
#
# {{ end }}
# {{- end }}
# {{- end }}
# ```

# %% [markdown]
# The [syntax](https://pkg.go.dev/text/template#hdr-Actions) is a bit hard to read, but ignore that for now.  Where did this prompt come from?  After a bit of google fu, we can see that it originated from this [Llama 3.1 documentation on "JSON based" tool calling](https://www.llama.com/docs/model-cards-and-prompt-formats/llama3_1/#json-based-tool-calling).
#
# From the same page, here is an example of such a prompt:
# ```
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
# Today Date: 23 July 2024
#
# When you receive a tool call response, use the output to format an answer to the orginal user question.
#
# You are a helpful assistant with tool calling capabilities.<|eot_id|><|start_header_id|>user<|end_header_id|>
#
# Given the following functions, please respond with a JSON for a function call with its proper arguments that best answers the given prompt.
#
# Respond in the format {"name": function name, "parameters": dictionary of argument name and its value}. Do not use variables.
#
# {
#     "type": "function",
#     "function": {
#     "name": "get_current_conditions",
#     "description": "Get the current weather conditions for a specific location",
#     "parameters": {
#         "type": "object",
#         "properties": {
#         "location": {
#             "type": "string",
#             "description": "The city and state, e.g., San Francisco, CA"
#         },
#         "unit": {
#             "type": "string",
#             "enum": ["Celsius", "Fahrenheit"],
#             "description": "The temperature unit to use. Infer this from the user's location."
#         }
#         },
#         "required": ["location", "unit"]
#     }
#     }
# }
#
# Question: what is the weather like in San Fransisco?<|eot_id|><|start_header_id|>assistant<|end_header_id|>
# ```
#
# So what prompt is Ollama sending to Llama 3.2?  Let's take a look.

# %%
def get_raw_prompt():
  template = !cat nohup.out | fgrep "chat request" | sed -e 's/.*prompt="\(.*\)"/\1/'
  return [s.encode().decode('unicode_escape') for s in template]

# !ollama pull llama3.2 2>/dev/null
!>nohup.out # Truncate ollama output
react_chat("Hi.", model=ChatOllama(model="llama3.2"))
print(get_raw_prompt()[0])
# Out:
# <|start_header_id|>system<|end_header_id|>
#
# Cutting Knowledge Date: December 2023
#
# When you receive a tool call response, use the output to format an answer to the orginal user question.
#
# You are a helpful assistant with tool calling capabilities.<|eot_id|><|start_header_id|>user<|end_header_id|>
#
# Given the following functions, please respond with a JSON for a function call with its proper arguments that best answers the given prompt.
#
# Respond in the format {"name": function name, "parameters": dictionary of argument name and its value}. Do not use variables.
#
# {"type":"function","function":{"name":"foobar","description":"Computes the foobar function.","parameters":{"type":"object","required":["input"],"properties":{"input":{"type":"integer","description":""}}}}}
#
# Hi.<|eot_id|><|start_header_id|>assistant<|end_header_id|>

# %% [markdown]
# We can see a few minor differences:
# 1. Ollama's prompt is missing the "Today Date" line.
# 2. The Llama 3.1 example prompt has line breaks in the tool JSON, but the Ollama
# prompt does not.
#
# But neither of these seem likely to be a big problem.
#
# A larger question might be "Why is Ollama using a Llama 3.1 prompt for Llama 3.2?"  And perhaps and even larger one is "What prompt **should** it be using?"
#
# The answer is complicated.  It turns out that the Llama model website is actually **not** the authoritative source for prompt formats.  In [this thread](https://github.com/meta-llama/llama-stack-apps/issues/36), a user notes that there are at least three *different* prompt formats suggested for Llama 3.1:
# 1. [The Llama 3.1 model website](https://www.llama.com/docs/model-cards-and-prompt-formats/llama3_1#-tool-calling-(8b/70b/405b)-)
# 2. [Meta's Llama tooling and documentation](https://github.com/meta-llama/llama-models/blob/main/models/llama3_1/prompt_format.md)
# 3. [The HuggingFace model's chat
#    template](https://huggingface.co/meta-llama/Llama-3.1-8B/blob/main/tokenizer_config.json)
#
# A Meta employee states that the prompt in the tooling is the correct one.  And this [prompt](https://github.com/meta-llama/llama-models/blob/main/models/llama3_1/prompt_format.md#input-prompt-format-5) is pretty different!
#
# ```
# <|begin_of_text|><|start_header_id|>system<|end_header_id|>
#
# Environment: ipython
#
# Cutting Knowledge Date: December 2023
# Today Date: 21 September 2024
#
# You are a helpful assistant.
# <|eot_id|><|start_header_id|>user<|end_header_id|>
#
# Answer the user's question by making use of the following functions if needed.
# If none of the function can be used, please say so.
# Here is a list of functions in JSON format:
# {
#     "type": "function",
#     "function": {
#         "name": "trending_songs",
#         "description": "Returns the trending songs on a Music site",
#         "parameters": {
#             "type": "object",
#             "properties": [
#                 {
#                     "n": {
#                         "type": "object",
#                         "description": "The number of songs to return"
#                     }
#                 },
#                 {
#                     "genre": {
#                         "type": "object",
#                         "description": "The genre of the songs to return"
#                     }
#                 }
#             ],
#             "required": ["n"]
#         }
#     }
# }
#
# Return function calls in JSON format.<|eot_id|><|start_header_id|>user<|end_header_id|>
#
# Use tools to get latest trending songs<|eot_id|><|start_header_id|>assistant<|end_header_id|>
#
#
# ```

# %% [markdown]
# ### Some Prompt Experiments
#
# And are the prompts the problem?
#
# To help answer this question, I made a few copies of the Llama 3.2 model but with different prompts:
#
# 1. [ejschwar/llama3.2-prompt-testing:llama3.1-tooling-prompt](https://ollama.com/ejschwar/llama3.2-prompt-testing:llama3.1-tooling-prompt) Inspired by the [prompt](https://ollama.com/ejschwar/llama3.2-prompt-testing:llama3.1-tooling-prompt) for Llama 3.1 in the official Llama tooling.
# > You are a helpful assistant.
# > <|eot_id|><|start_header_id|>user<|end_header_id|>
# >
# > Answer the user's question by making use of the following functions if needed.
# > If none of the function can be used, please say so.
# > Here is a list of functions in JSON format:
#
# 2. [ejschwar/llama3.2-prompt-testing:llama3.2-tooling-prompt-system](https://ollama.com/ejschwar/llama3.2-prompt-testing:llama3.2-tooling-prompt-system) Inspired by the [prompt](https://github.com/meta-llama/llama-models/blob/main/models/llama3_2/text_prompt_format.md#zero-shot-function-calling) for Llama 3.2 in the official Llama tooling.
# > You are an expert in composing functions. You are given a question and a set of possible functions.
# > Based on the question, you will need to make one or more function/tool calls to achieve the purpose.
# > If none of the function can be used, point it out. If the given question lacks the parameters required by the function,
# > also point it out. You should only return the function call in tools call sections.
# >
# > If you decide to invoke any of the function(s), you MUST put it in the format of [func_name1(params_name1=params_value1, params_name2=params_value2...), func_name2(params)]
# > You SHOULD NOT include any other text in the response.
# >
# > Here is a list of functions in JSON format that you can invoke.
#
# Let's see if these work any better.

# %%
ed_models = [
  "ejschwar/llama3.2-prompt-testing:llama3.1-tooling-prompt",
  "ejschwar/llama3.2-prompt-testing:llama3.2-tooling-prompt-system",
]

for m in ed_models:
  print(f"Model: {m}")
  # !ollama pull {m} 2>/dev/null
  r = run_and_print_experiment(ChatOllama(model=m), m)
  all.append(r)
  print(r)

# %% [markdown]
# Remember that Llama 3.2 with the default Ollama prompt scored 1.7 out of 4.0.  So `llama3.1-tooling-prompt` seems like an improvement!  Oddly enough, the `llama3.2-tooling-prompt-system` did far worse on basic tool usage, but improved the ability to chat.  Let's see what happened.

# %%
m = ChatOllama(model="ejschwar/llama3.2-prompt-testing:llama3.2-tooling-prompt-system")
pprint.pprint(react_chat("What is foobar(32)?", model=m))

# %% [markdown]
# It may not be obvious to you, but Llama requested to call `foobar(32)`, but did so in a format that Ollama did not understand.  As [this comment](https://github.com/ollama/ollama/blob/da09488fbfc437c55a94bc5374b0850d935ea09f/server/model.go#L302) states:
# > // mxyng: this only really works if the input contains tool calls in some JSON format
#
# So, I made a slight change to the prompt to allow function calls to be reported in JSON syntax.  The new prompt is called [llama3.2-tooling-prompt-system-plus-json](https://ollama.com/ejschwar/llama3.2-prompt-testing:llama3.2-tooling-prompt-system-plus-json).

# %%
ed_models = ed_models + ["ejschwar/llama3.2-prompt-testing:llama3.2-tooling-prompt-system-plus-json"]
for m in ed_models[-1:]:
  print(f"Model: {m}")
  # !ollama pull {m} 2>/dev/null
  r = run_and_print_experiment(ChatOllama(model=m), m)
  all.append(r)
  print(r)
# Out:
# Model: ejschwar/llama3.2-prompt-testing:llama3.2-tooling-prompt-system-plus-json
# Recursion limit of 25 reached without hitting a stop condition. You can increase the limit by setting the `recursion_limit` config key.
# For troubleshooting, visit: https://python.langchain.com/docs/troubleshooting/errors/GRAPH_RECURSION_LIMIT
# Question 1: Can the react agent use a tool correctly when explicitly asked? (ejschwar/llama3.2-prompt-testing:llama3.2-tooling-prompt-system-plus-json) success rate: 0.0
# Question 2: Does the react agent invoke a tool when it shouldn't? (ejschwar/llama3.2-prompt-testing:llama3.2-tooling-prompt-system-plus-json) success rate: 0.6
# Question 3: Does the react agent lose the ability to answer questions unrelated to tools? (ejschwar/llama3.2-prompt-testing:llama3.2-tooling-prompt-system-plus-json) success rate: 0.6
# Question 4: Does the react agent lose the ability to chat? (ejschwar/llama3.2-prompt-testing:llama3.2-tooling-prompt-system-plus-json) success rate: 1.0
# {'q1': 0.0, 'q2': 0.6, 'q3': 0.6, 'q4': 1.0, 'model': 'ejschwar/llama3.2-prompt-testing:llama3.2-tooling-prompt-system-plus-json', 'total': 2.2}

# %%
m = ChatOllama(model="ejschwar/llama3.2-prompt-testing:llama3.2-tooling-prompt-system-plus-json")
pprint.pprint(react_chat("What is foobar(32)?", model=m))
# Out:
# ('None of the given function can be used. The input to foobar is always 17, '
#  'not any integer value.',
#  {'messages': [HumanMessage(content='What is foobar(32)?', additional_kwargs={}, response_metadata={}, id='96752588-43d6-4a2f-88c9-aed0ca2ae04e'),
#                AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'ejschwar/llama3.2-prompt-testing:llama3.2-tooling-prompt-system-plus-json', 'created_at': '2024-12-10T17:00:55.011890752Z', 'done': True, 'done_reason': 'stop', 'total_duration': 282226858, 'load_duration': 21947532, 'prompt_eval_count': 209, 'prompt_eval_duration': 7000000, 'eval_count': 16, 'eval_duration': 252000000, 'message': Message(role='assistant', content='', images=None, tool_calls=[ToolCall(function=Function(name='foobar', arguments={'input': '32'}))])}, id='run-8a9b02d0-bce3-4008-a019-4bdd385e58b6-0', tool_calls=[{'name': 'foobar', 'args': {'input': 32}, 'id': '998e4d4f-9409-4ef8-be18-1ca42d58a571', 'type': 'tool_call'}], usage_metadata={'input_tokens': 209, 'output_tokens': 16, 'total_tokens': 225}),
#                ToolMessage(content='34', name='foobar', id='c2d5ad3d-ad31-4218-8455-c85a7463da6c', tool_call_id='998e4d4f-9409-4ef8-be18-1ca42d58a571'),
#                AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'ejschwar/llama3.2-prompt-testing:llama3.2-tooling-prompt-system-plus-json', 'created_at': '2024-12-10T17:00:55.293110063Z', 'done': True, 'done_reason': 'stop', 'total_duration': 275014057, 'load_duration': 26333757, 'prompt_eval_count': 235, 'prompt_eval_duration': 7000000, 'eval_count': 15, 'eval_duration': 239000000, 'message': Message(role='assistant', content='', images=None, tool_calls=[ToolCall(function=Function(name='foobar', arguments={'input': 33}))])}, id='run-011867fe-3fba-4d4d-b2ab-93c55119242a-0', tool_calls=[{'name': 'foobar', 'args': {'input': 33}, 'id': '67c4d149-ef0c-4ff4-b3d3-db20389cc420', 'type': 'tool_call'}], usage_metadata={'input_tokens': 235, 'output_tokens': 15, 'total_tokens': 250}),
#                ToolMessage(content='35', name='foobar', id='bd8a85ae-4936-45ca-90e1-63e9af6c2f92', tool_call_id='67c4d149-ef0c-4ff4-b3d3-db20389cc420'),
#                AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'ejschwar/llama3.2-prompt-testing:llama3.2-tooling-prompt-system-plus-json', 'created_at': '2024-12-10T17:00:55.569043018Z', 'done': True, 'done_reason': 'stop', 'total_duration': 270232179, 'load_duration': 21967253, 'prompt_eval_count': 261, 'prompt_eval_duration': 6000000, 'eval_count': 15, 'eval_duration': 238000000, 'message': Message(role='assistant', content='', images=None, tool_calls=[ToolCall(function=Function(name='foobar', arguments={'input': 17}))])}, id='run-4aaf89e3-e504-4b85-8370-cda6f3c08417-0', tool_calls=[{'name': 'foobar', 'args': {'input': 17}, 'id': 'd18f5fb6-135d-4bf5-b61d-fecc3fe44b8e', 'type': 'tool_call'}], usage_metadata={'input_tokens': 261, 'output_tokens': 15, 'total_tokens': 276}),
#                ToolMessage(content='19', name='foobar', id='351ee535-cc8a-4a19-8010-75cb9afa4e97', tool_call_id='d18f5fb6-135d-4bf5-b61d-fecc3fe44b8e'),
#                AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'ejschwar/llama3.2-prompt-testing:llama3.2-tooling-prompt-system-plus-json', 'created_at': '2024-12-10T17:00:55.851708394Z', 'done': True, 'done_reason': 'stop', 'total_duration': 276675109, 'load_duration': 23976753, 'prompt_eval_count': 287, 'prompt_eval_duration': 7000000, 'eval_count': 15, 'eval_duration': 241000000, 'message': Message(role='assistant', content='', images=None, tool_calls=[ToolCall(function=Function(name='foobar', arguments={'input': 27}))])}, id='run-a00ab68e-e632-456c-9a4d-a75c61504b5d-0', tool_calls=[{'name': 'foobar', 'args': {'input': 27}, 'id': '494de716-136b-4541-9cbb-ae3f36966300', 'type': 'tool_call'}], usage_metadata={'input_tokens': 287, 'output_tokens': 15, 'total_tokens': 302}),
#                ToolMessage(content='29', name='foobar', id='bbdf1fd6-8959-4aa7-a96a-c8a1b3c14c4f', tool_call_id='494de716-136b-4541-9cbb-ae3f36966300'),
#                AIMessage(content='', additional_kwargs={}, response_metadata={'model': 'ejschwar/llama3.2-prompt-testing:llama3.2-tooling-prompt-system-plus-json', 'created_at': '2024-12-10T17:00:56.13570772Z', 'done': True, 'done_reason': 'stop', 'total_duration': 278233207, 'load_duration': 22075352, 'prompt_eval_count': 313, 'prompt_eval_duration': 7000000, 'eval_count': 15, 'eval_duration': 242000000, 'message': Message(role='assistant', content='', images=None, tool_calls=[ToolCall(function=Function(name='foobar', arguments={'input': 40}))])}, id='run-df29787c-e3a7-4d45-b530-351b948f1a54-0', tool_calls=[{'name': 'foobar', 'args': {'input': 40}, 'id': '6894086e-1ad8-4e01-8711-2103deceb849', 'type': 'tool_call'}], usage_metadata={'input_tokens': 313, 'output_tokens': 15, 'total_tokens': 328}),
#                ToolMessage(content='42', name='foobar', id='e78654d8-d1e5-4b7d-b75f-ad6b080b7646', tool_call_id='6894086e-1ad8-4e01-8711-2103deceb849'),
#                AIMessage(content='None of the given function can be used. The input to foobar is always 17, not any integer value.', additional_kwargs={}, response_metadata={'model': 'ejschwar/llama3.2-prompt-testing:llama3.2-tooling-prompt-system-plus-json', 'created_at': '2024-12-10T17:00:56.58500286Z', 'done': True, 'done_reason': 'stop', 'total_duration': 442851183, 'load_duration': 22182403, 'prompt_eval_count': 339, 'prompt_eval_duration': 7000000, 'eval_count': 25, 'eval_duration': 406000000, 'message': Message(role='assistant', content='None of the given function can be used. The input to foobar is always 17, not any integer value.', images=None, tool_calls=None)}, id='run-fb0689ab-ae0f-4df0-981f-50f9cf7a5018-0', usage_metadata={'input_tokens': 339, 'output_tokens': 25, 'total_tokens': 364})]})

# %% [markdown]
# I'm not exactly sure what went wrong, but there is probably an issue in the way that the tool result was communicated back to the model.

# %% [markdown]
# So: are prompts the problem?  In Ollama's Llama 3.2, the answer seems to be yes, at least partially.

# %% [markdown]
# ## Is Post-processing the Problem?
#
# Rubra has an interesting [benchmark](https://docs.rubra.ai/benchmark/) where they claim to have solved this problem.  You can try their models in a [HF space](https://huggingface.co/spaces/sanjay920/rubra-v0.1-function-calling) and they seemed to work well -- they don't call tools in response to "Hi." at least.
#
# Unfortunately, Rubra requires their own forked version of llama.cpp, so I haven't seriously tried it.  Interestingly, the benchmark page also list a variety of other post-processors for various models including Mistral, Hermes, and groq.  So maybe that explains the poor performance of Mistral and Hermes.  But groq worked pretty well for us even though we didn't use their library.
#
# Maybe this also explains why BFCL reports such low scores as well -- they aren't implementing custom parsers for each model type.

# %% [markdown]
# ## What Do Others Think?
#
# Fireworks is another group who also [claims to have solved this problem](https://fireworks.ai/blog/firefunction-v2-launch-post).  Here's what they is wrote:
#
# > Most open-source models have focused on narrow use cases. They introduce function calling capabilities through an aggressive fine-tuning process that focuses narrowly on function calling and erases the native capabilities of the base model. **This creates models that perform well on benchmarks (usually emphasizing single-turn, forced function calling). However these models (1) Don’t generalize outside of benchmarks to real world scenarios and (2) Are poor at general reasoning and chat.**

# %% [markdown]
# # Conclusion: Why Don't Local Tool-calling Agents Work?
#
# I wish I had a simple answer here.  Prompt management seems to be at least part of the problem.  Ollama's developers have created prompt formats for popular models like Llama 3.2.  And, at least for Llama 3.2, they used the wrong prompt.  That being said, Meta also needs to be doing a better job documenting their prompt formats.
#
# Ollama also doesn't advertise it, but it only supports tool outputs that are output in JSON format.  This could be another problem.
#
# Finally, many models seem to have custom post-processing code.  I'm just using Ollama and whatever prompts are included.  So perhaps the post-processing code is needed for some models.
#
# Finally, because I ran these experiments on Colab, I was limited to smaller models.  It's possible that smaller models just don't work that well for this problem, and maybe we need larger models.
#
# Hopefully there will be a part two to the blog post where I solve the mystery.  But for now, hopefully I've convinced you that there's a problem.
#
# If you've had any experiences with these types of problems (or success stories), I'd love to hear from you.
